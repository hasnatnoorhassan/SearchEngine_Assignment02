# %%
import pandas as pd
df = pd.read_csv("enwiki-20170820.csv", nrows=500)

merged_df = df.groupby('ARTICLE_ID').agg({'TITLE': 'first', 'SECTION_TEXT': ' '.join})
merged_df.rename(columns={'SECTION_TEXT': 'FULL_TEXT'}, inplace=True)
# merged_df = merged_df.sort_values(by='TITLE')

#merged_df.to_csv('merged_articles.csv', index=False)

merged_df
# Out:
#                                                TITLE  \
# ARTICLE_ID
# 3                                                  A
# 25                                             ASCII
# 41                         Aberdeen (disambiguation)
# 6                                    Abraham Lincoln
# 9           Academy Award for Best Production Design
# 10                                    Academy Awards
# 5                                           Achilles
# 11                                           Actrius
# 40                                               Ada
# 31                             Afroasiatic languages
# 21                              Agricultural science
# 38                                       Agriculture
# 4                                            Alabama
# 16                                      Alain Connes
# 37                                            Alaska
# 2                                             Albedo
# 22                                           Alchemy
# 39                                     Aldous Huxley
# 42                                             Algae
# 18                                           Algeria
# 23                                             Alien
# 17                                        Allan Dwan
# 14                                          Altruism
# 34                      American Football Conference
# 36                                         Amphibian
# 8                               An American in Paris
# 43                              Analysis of variance
# 0                                          Anarchism
# 32                                           Andorra
# 29                                      Andre Agassi
# 35                                       Animal Farm
# 12                                   Animalia (book)
# 27                                         Animation
# 20                                      Anthropology
# 28                                            Apollo
# 7                                          Aristotle
# 33                                   Arithmetic mean
# 24                                        Astronomer
# 26                           Austin (disambiguation)
# 30                           Austroasiatic languages
# 1                                             Autism
# 15                                          Ayn Rand
# 13                         International Atomic Time
# 19                 List of Atlas Shrugged characters
#
#                                                     FULL_TEXT
# ARTICLE_ID
# 3           \n\n\n\n\n\n\nWriting cursive forms of A\n'''A...
# 25          \n\n\n\n'''ASCII''' ( ) abbreviated from '''Am...
# 41          \n'''Aberdeen''' is a city in Scotland United ...
# 6           \n\n\n\n\n\n'''Abraham Lincoln''' (; February ...
# 9           \n\n\nThe '''Academy Award for Best Production...
# 10          \n\n\n\n\nThe '''Academy Awards''' now known o...
# 5           \n\nAchilles and the Nereid Cymothoe Attic red...
# 11          \n\n\n\n'''''Actresses''''' (Catalan: '''''Act...
# 40          \n\n'''Ada''' may refer to:\n\n \n===Africa===...
# 31          \n\n\n\n'''Afroasiatic''' ('''Afro-Asiatic''')...
# 21          \n\n\n'''Agricultural science''' is a broad mu...
# 38          \n\n\n\nFields in Záhorie (Slovakia)a typical ...
# 4           \n\n\n\n\n\n\n'''Alabama''' () is a state in t...
# 16          \n\n\n'''Alain Connes''' (; born 1 April 1947)...
# 37          \n\n\n\n\n\n\n\n\n'''Alaska''' () is a U.S. st...
# 2           \n\nPercentage of diffusely reflected sunlight...
# 22          \nKimiya-yi sa'ādat (''The Alchemy of Happines...
# 39          \n\n\n\n'''Aldous Leonard Huxley''' (; 26 July...
# 42          \n\n\n\n\n'''Algae''' (; singular '''alga''' )...
# 18          \n\n\n\n\n\n\n\n'''Algeria''' ( '''';  ''''; )...
# 23          \n\n\n'''Alien''' primarily refers to:\n* Extr...
# 17          \n\n\n'''Allan Dwan''' (3 April 1885 – 28 Dece...
# 14          \n\nGiving alms to the poor is often considere...
# 34          \n\n\n\nThe '''American Football Conference'''...
# 36          \n\n\n\n\n'''Amphibians''' are ectothermic tet...
# 8           \n\n\n\n'''''An American in Paris''''' is a ja...
# 43          \n\n'''Analysis of variance''' ('''ANOVA''') i...
# 0           \n\n\n\n\n\n'''Anarchism''' is a political phi...
# 32          \n\n\n\n\n\n\n'''Andorra''' (;  ) officially t...
# 29          \n\n\n'''Andre Kirk Agassi''' (; born April 29...
# 35          \n\n\n\n\n\n\n'''''Animal Farm''''' is an alle...
# 12          \n\n\n'''''Animalia''''' is an illustrated chi...
# 27          \n\n\n\n\n'''Animation''' is the process of ma...
# 20          \n\n\n\n'''Anthropology''' is the study of var...
# 28          \n\n\n\n\n\n\n\n\n\n'''Apollo''' (Attic Ionic ...
# 7           \n\n\n\n\n'''Aristotle''' (;   ''Aristotélēs''...
# 33          \n\n\n\nIn mathematics and statistics the '''a...
# 24          \n\nThe Astronomer'' by Johannes Vermeer\n\nAn...
# 26          \n'''Austin''' is the capital of Texas in the ...
# 30          \n\n\n\n\nThe '''Austroasiatic languages''' in...
# 1           \n\n\n \n\n\n\n\n'''Autism''' is a neurodevelo...
# 15          \n\n\n'''Ayn Rand''' (; born '''Alisa Zinov'ye...
# 13          '''International Atomic Time''' ('''TAI''' fro...
# 19          \nThis is a list of characters in Ayn Rand's n...

# %%
import re
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import wordnet

merged_df=pd.read_csv("pleasework.csv",header=None)
merged_df.columns = ['ARTICLE_ID', 'TITLE', 'FULL_TEXT']
def is_adverb(tag):
    return tag.startswith('RB')

def preprocess_text(text):
    porter_stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer()

    tokens = nltk.word_tokenize(text)
    tagged_tokens = nltk.pos_tag(tokens)
    
    tokens = [token.lower() for token in tokens]
 
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    tokens = [re.sub(r'[^a-zA-Z0-9]', '', token) for token in tokens]

    tokens = [token for token in tokens if token]

    stemmed_tokens = [porter_stemmer.stem(token) for token in tokens]

    lemmatized_tokens = []
    for token, tag in tagged_tokens:
        if is_adverb(tag):
            lemmatized_tokens.append(lemmatizer.lemmatize(token, pos=wordnet.ADV))
        else:
            lemmatized_tokens.append(lemmatizer.lemmatize(token))

    preprocessed_text = ' '.join(lemmatized_tokens)
    
    return preprocessed_text

merged_df['FULL_TEXT'] = merged_df['FULL_TEXT'].apply(preprocess_text)

# %%
merged_df
# Out:
#       ARTICLE_ID              TITLE  \
# 0              0          Anarchism
# 1              1             Autism
# 2              2             Albedo
# 3              3                  A
# 4              4            Alabama
# ...          ...                ...
# 1110        1110            Antacid
# 1111        1111     Antidiarrhoeal
# 1112        1112    Áed mac Cináeda
# 1113        1113      Abdul Hamid I
# 1114        1114  Abdur Rahman Khan
#
#                                               FULL_TEXT
# 0     political philosophy based voluntary often sta...
# 1     disorder social interaction verbal communicati...
# 2     percentage diffusely reflected sunlight relati...
# 3     writing cursive plural aes first letter first ...
# 4     state southeastern region united bordered nort...
# ...                                                 ...
# 1110  antacid substance stomach acidity used relieve...
# 1111  drug drug medication symptomatic relief electr...
# 1112  mac born son mac king brother white chronicle ...
# 1113  march sultan empire empire born younger son su...
# 1114  khan emir third son khan grandson khan khan wr...
#
# [1115 rows x 3 columns]

# %%
merged_df.to_csv('merged_articles.csv', index=True)

# %%
from nltk.tokenize import word_tokenize
vocabulary = set()
for text in merged_df['FULL_TEXT']:
    tokens = word_tokenize(text)
    vocabulary.update(tokens)
sorted_vocabulary = sorted(vocabulary)

print("Vocabulary size:", len(sorted_vocabulary))
print("Sample vocabulary terms:", sorted_vocabulary[1500:2000])
# Out:
# Vocabulary size: 30392
# Sample vocabulary terms: ['appalling', 'appanage', 'apparatus', 'apparel', 'apparent', 'apparently', 'apparition', 'appeal', 'appealing', 'appear', 'appearance', 'appease', 'appellant', 'appellate', 'appellation', 'appellee', 'append', 'appendage', 'appendectomy', 'appendice', 'appendicitis', 'appendicular', 'appendix', 'appetite', 'appetitive', 'appetizer', 'applaud', 'applause', 'apple', 'appliance', 'applicability', 'applicable', 'applicant', 'application', 'applicator', 'applied', 'apply', 'appoint', 'appointment', 'apportionment', 'appraisal', 'appraising', 'appreciable', 'appreciably', 'appreciate', 'appreciation', 'appreciative', 'apprehend', 'apprehension', 'apprehensive', 'apprentice', 'apprenticeship', 'approach', 'approaching', 'approbation', 'appropriate', 'appropriately', 'appropriateness', 'appropriation', 'approval', 'approve', 'approvingly', 'approximate', 'approximately', 'approximation', 'apraxia', 'apricot', 'apron', 'apse', 'apt', 'aptitude', 'aptly', 'aqua', 'aquacultural', 'aquaculture', 'aquarium', 'aquatic', 'aquatone', 'aqueduct', 'aqueous', 'aquifer', 'aquiline', 'aquo', 'ar', 'ara', 'arabesque', 'arable', 'arachidonic', 'arad', 'arango', 'arapaima', 'arar', 'arba', 'arbiter', 'arbitral', 'arbitrarily', 'arbitrariness', 'arbitrary', 'arbitrate', 'arbitration', 'arbitrator', 'arbor', 'arboreal', 'arboreally', 'arborescent', 'arboretum', 'arborization', 'arbutus', 'arc', 'arca', 'arcade', 'arcadian', 'arcane', 'arcanum', 'arch', 'archaeologic', 'archaeological', 'archaeologically', 'archaeologist', 'archaeology', 'archaic', 'archaism', 'archaistic', 'archangel', 'archbishop', 'archbishopric', 'archdeacon', 'archdeaconry', 'archdiocese', 'archduchess', 'archduchy', 'archduke', 'arche', 'arched', 'archenteron', 'archer', 'archery', 'archetypal', 'archetype', 'archetypical', 'archiepiscopal', 'archiepiscopate', 'archimandrite', 'arching', 'archipelagic', 'archipelago', 'architect', 'architectonic', 'architectural', 'architecturally', 'architecture', 'archival', 'archive', 'archivist', 'archon', 'archpriest', 'archy', 'arcing', 'arctic', 'arcuate', 'ardent', 'ardently', 'ardor', 'arduous', 'area', 'areal', 'arecoline', 'arena', 'arend', 'arete', 'argel', 'argent', 'argentine', 'argillaceous', 'arginine', 'argo', 'argon', 'argot', 'arguable', 'argue', 'argument', 'argumental', 'argumentation', 'argumentative', 'argyria', 'aria', 'arid', 'aridity', 'ariel', 'aright', 'arise', 'arisen', 'arista', 'aristocracy', 'aristocrat', 'aristocratic', 'arithmetic', 'arithmetical', 'arithmetically', 'arithmetician', 'arithmometer', 'arjun', 'ark', 'arles', 'arm', 'armada', 'armadillo', 'armagnac', 'armament', 'armature', 'armchair', 'armed', 'armillary', 'arming', 'armistice', 'armlet', 'armor', 'armored', 'armorer', 'armory', 'armpit', 'armrest', 'armure', 'army', 'arn', 'aroma', 'aromatic', 'aromatization', 'arose', 'around', 'arousal', 'arouse', 'arpeggio', 'arpent', 'arracacha', 'arraignment', 'arrange', 'arrangement', 'arranger', 'arras', 'array', 'arrest', 'arresting', 'arrestment', 'arrestor', 'arrhythmia', 'arrival', 'arrive', 'arrogance', 'arrogant', 'arrogantly', 'arrogation', 'arrow', 'arrowhead', 'arrowsmith', 'arroyo', 'arse', 'arsenal', 'arsenate', 'arsenic', 'arsenical', 'arsenide', 'arsenite', 'arsenopyrite', 'arsenous', 'arsine', 'arson', 'arsonium', 'arsphenamine', 'art', 'artefact', 'arterial', 'arteriovenous', 'artery', 'artful', 'artfully', 'arthritic', 'arthritis', 'arthropod', 'artichoke', 'article', 'articular', 'articulate', 'articulated', 'articulation', 'articulatory', 'artifact', 'artifice', 'artificial', 'artificiality', 'artificially', 'artillery', 'artisan', 'artist', 'artiste', 'artistic', 'artistically', 'artistry', 'artless', 'aru', 'ary', 'aryl', 'as', 'asbestos', 'ascend', 'ascendancy', 'ascendant', 'ascending', 'ascension', 'ascent', 'ascertain', 'ascertainment', 'ascetic', 'asceticism', 'ascham', 'ascii', 'asclepiad', 'ascorbic', 'ascot', 'ascribe', 'ascription', 'aseptic', 'asexual', ...

# %%
vocabulary_with_ids = [(idx, term) for idx, term in enumerate(sorted_vocabulary)]
vocabulary_with_ids[:15]
# Out:
# Sample vocabulary terms with IDs (as list of tuples):
# [(0, 'aa'),
#  (1, 'aal'),
#  (2, 'aardvark'),
#  (3, 'aardwolf'),
#  (4, 'aba'),
#  (5, 'abac'),
#  (6, 'abaca'),
#  (7, 'abacist'),
#  (8, 'abacus'),
#  (9, 'abalone'),
#  (10, 'abampere'),
#  (11, 'abandon'),
#  (12, 'abandoned'),
#  (13, 'abandonment'),
#  (14, 'abate')]

# %%
merged_df
# Out:
#       ARTICLE_ID              TITLE  \
# 0              0          Anarchism
# 1              1             Autism
# 2              2             Albedo
# 3              3                  A
# 4              4            Alabama
# ...          ...                ...
# 1110        1110            Antacid
# 1111        1111     Antidiarrhoeal
# 1112        1112    Áed mac Cináeda
# 1113        1113      Abdul Hamid I
# 1114        1114  Abdur Rahman Khan
#
#                                               FULL_TEXT
# 0     political philosophy based voluntary often sta...
# 1     disorder social interaction verbal communicati...
# 2     percentage diffusely reflected sunlight relati...
# 3     writing cursive plural aes first letter first ...
# 4     state southeastern region united bordered nort...
# ...                                                 ...
1), (5789, 1), (5791, 1), (5803, 1), (5807, 1), (5812, 3), (5819, 3), (5820, 1), (5824, 7), (5829, 2), (5867, 1), (5869, 1), (5898, 1), (5902, 1), (5917, 1), (5918, 9), (5934, 1), (5944, 1), (5949, 1), (5951, 1), (5960, 1), (5981, 1), (5988, 7), (5992, 1), (6135, 1), (6142, 1), (6211, 2), (6233, 1), (6237, 3), (6238, 1), (6269, 4), (6274, 1), (6285, 1), (6344, 1), (6356, 1), (6365, 1), (6387, 4), (6388, 1), (6398, 1), (6442, 1), (6447, 1), (6448, 2), (6453, 4), (6472, 1), (6491, 2), (6525, 1), (6552, 1), (6598, 5), (6655, 1), (6656, 4), (6783, 1), (6801, 1), (6860, 2), (6867, 1), (6878, 10), (6884, 4), (6916, 2), (6945, 1), (6964, 1), (6965, 2), (6986, 1), (7025, 5), (7047, 1), (7048, 1), (7060, 1), (7072, 1), (7075, 1), (7078, 2), (7112, 1), (7116, 1), (7133, 1), (7184, 1), (7197, 1), (7199, 3), (7201, 1), (7219, 1), (7249, 1), (7276, 1), (7326, 1), (7347, 1), (7375, 1), (7388, 1), (7391, 1), (7406, 2), (7465, 1), (7467, 6), (7474, 1), (7587, 2), (7595, 1), (7608, 2), (7609, 1), (7610, 8), (7646, 1), (7742, 5), (7743, 1), (7744, 1), (7749, 3), (7775, 2), (7788, 1), (7845, 1), (7849, 1), (7871, 1), (7931, 1), (7937, 1), (7948, 1), (8015, 1), (8056, 1), (8071, 1), (8072, 3), (8075, 1), (8104, 4), (8111, 1), (8117, 3), (8122, 1), (8154, 1), (8155, 2), (8156, 2), (8261, 1), (8308, 2), (8345, 3), (8382, 1), (8423, 1), (8448, 3), (8533, 1), (8534, 1), (8565, ...

# %%
print(len(document_tf_filtered[1][1]))
# Out:
# 1228

# %%
# import numpy as np

# def calculate_idf(document_tf):
    
#     document_frequency = {}
#     for _, tf_repr in document_tf:
#         unique_terms = set(term_id for term_id, _ in tf_repr)
#         for term_id in unique_terms:
#             document_frequency[term_id] = document_frequency.get(term_id, 0) + 1
#     total_documents = len(document_tf)
#     idf_representation = {term_id: np.log10(total_documents / df) for term_id, df in document_frequency.items()}
    
#     return idf_representation


# idf_representation = calculate_idf(document_tf_filtered)

# print("IDF representation for the first few terms:")
# for term_id, idf in list(idf_representation.items())[:10]:
#     print(f"Term ID: {term_id}, IDF: {idf}")
# Function to calculate IDF for each term in the vocabulary
def calculate_idf(document_tf):

    document_frequency = {}
    for _, tf_repr in document_tf:
        unique_terms = set(term_id for term_id, _ in tf_repr)
        for term_id in unique_terms:
            document_frequency[term_id] = document_frequency.get(term_id, 0) + 1
            
    idf_representation = [(term_id, df) for term_id, df in document_frequency.items()]
    return idf_representation

idf_representation = calculate_idf(document_tf)
# Out:
# IDF representation for the first few terms:
# Term ID: 0, Number of Documents: 1115
# Term ID: 1, Number of Documents: 1115
# Term ID: 2, Number of Documents: 1115
# Term ID: 3, Number of Documents: 1115
# Term ID: 4, Number of Documents: 1115
(199, 1115), (200, 1115), (201, 1115), (202, 1115), (203, 1115), (204, 1115), (205, 1115), (206, 1115), (207, 1115), (208, 1115), (209, 1115), (210, 1115), (211, 1115), (212, 1115), (213, 1115), (214, 1115), (215, 1115), (216, 1115), (217, 1115), (218, 1115), (219, 1115), (220, 1115), (221, 1115), (222, 1115), (223, 1115), (224, 1115), (225, 1115), (226, 1115), (227, 1115), (228, 1115), (229, 1115), (230, 1115), (231, 1115), (232, 1115), (233, 1115), (234, 1115), (235, 1115), (236, 1115), (237, 1115), (238, 1115), (239, 1115), (240, 1115), (241, 1115), (242, 1115), (243, 1115), (244, 1115), (245, 1115), (246, 1115), (247, 1115), (248, 1115), (249, 1115), (250, 1115), (251, 1115), (252, 1115), (253, 1115), (254, 1115), (255, 1115), (256, 1115), (257, 1115), (258, 1115), (259, 1115), (260, 1115), (261, 1115), (262, 1115), (263, 1115), (264, 1115), (265, 1115), (266, 1115), (267, 1115), (268, 1115), (269, 1115), (270, 1115), (271, 1115), (272, 1115), (273, 1115), (274, 1115), (275, 1115), (276, 1115), (277, 1115), (278, 1115), (279, 1115), (280, 1115), (281, 1115), (282, 1115), (283, 1115), (284, 1115), (285, 1115), (286, 1115), (287, 1115), (288, 1115), (289, 1115), (290, 1115), (291, 1115), (292, 1115), (293, 1115), (294, 1115), (295, 1115), (296, 1115), (297, 1115), (298, 1115), (299, 1115), (300, 1115), (301, 1115), (302, 1115), (303, 1115), (304, 1115), (305, 1115), (306, 1115), (307, 1115), (308, 1115), (309, 1115), (310, 1115), (311, 1115), (312, 1115), (313, 1115), (314, 1115), (315, 1115), ( ...

# %%
# Function to calculate TF-IDF for each document
def calculate_tfidf(document_tf, idf_representation):
    tfidf_representation = []
    
    # Calculate TF-IDF for each document
    for article_id, tf_repr in document_tf:
        tfidf_repr = [(term_id, tf / idf) for term_id, tf in tf_repr for term_id_, idf in idf_representation if term_id == term_id_]
        tfidf_representation.append((article_id, tfidf_repr))
    
    return tfidf_representation

# Calculate TF-IDF for each document
tfidf_representation = calculate_tfidf(document_tf_filtered, idf_representation)

# Print TF-IDF representation of the first document
print("TF-IDF representation of the first document:")
print(tfidf_representation[0])
# Out:
# TF-IDF representation of the first document:
# (0, [(13, 0.0017937219730941704), (43, 0.0008968609865470852), (50, 0.0026905829596412557), (60, 0.0008968609865470852), (108, 0.0008968609865470852), (123, 0.0017937219730941704), (148, 0.0008968609865470852), (151, 0.0008968609865470852), (177, 0.0008968609865470852), (178, 0.0008968609865470852), (179, 0.012556053811659192), (180, 0.0008968609865470852), (183, 0.0008968609865470852), (195, 0.0008968609865470852), (201, 0.0008968609865470852), (230, 0.0008968609865470852), (259, 0.0008968609865470852), (279, 0.0017937219730941704), (283, 0.0008968609865470852), (286, 0.0008968609865470852), (292, 0.008071748878923767), (298, 0.006278026905829596), (299, 0.0026905829596412557), (300, 0.0026905829596412557), (301, 0.0008968609865470852), (302, 0.0008968609865470852), (326, 0.0008968609865470852), (343, 0.0008968609865